# %% [markdown]
# Reference: <a> https://www.youtube.com/watch?v=1ICRLYtkmNU&t=5251s</a>

# %%
# Import packages
import pathlib
import textwrap

import google.generativeai as genai

# used to securely store your API Key
from google.colab import userdata

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('.', '*')
  return Markdown(textwrap.indent(text, '>', predicate=lambda _: True))

# %% [markdown]
# Setup your API key

# %%
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyBIuUUOW_v-dl6H6J0ab1dXB5pInaHuH3U"

# %%
genai.configure(api_key="AIzaSyBIuUUOW_v-dl6H6J0ab1dXB5pInaHuH3U ")

# %%
# or
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m)
# Out:
# Model(name='models/gemini-1.0-pro',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.0 Pro',
#       description='The best model for scaling across a wide range of tasks',
#       input_token_limit=30720,
#       output_token_limit=2048,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.9,
#       top_p=1.0,
#       top_k=None)
# Model(name='models/gemini-1.0-pro-001',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.0 Pro 001 (Tuning)',
#       description=('The best model for scaling across a wide range of tasks. This is a stable '
#                    'model that supports tuning.'),
#       input_token_limit=30720,
#       output_token_limit=2048,
#       supported_generation_methods=['generateContent', 'countTokens', 'createTunedModel'],
#       temperature=0.9,
#       top_p=1.0,
#       top_k=None)
# Model(name='models/gemini-1.0-pro-latest',
#       base_model_id='',
# ...

# %% [markdown]
# <h1>Generate text from text inputs</h1>

# %% [markdown]
# For text-only prompts, use the gemini-pro model:

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
# )

# %%
# %%time
response = model.generate_content("Who get spiritually enlightend")
# Out:
# CPU times: user 158 ms, sys: 14.1 ms, total: 172 ms
# Wall time: 10.3 s

# %%
to_markdown(response.text)
# Out:
# >**Individuals who can potentially experience spiritual enlightenment:**
# >
# >**1* Seekers and Practitioners:**
# >* Those dedicated to spiritual practices, meditation, yoga, prayer, or other forms of contemplative inquiry*
# >
# >**2* Introspective Persons:**
# >* Individuals with a strong inner life who engage in self-reflection, self-awareness, and a search for meaning*
# >
# >**3* Experiencers of Significant Life Events:**
# >* People who undergo transformative experiences such as near-death experiences, profound grief, or major personal challenges*
# >* These events can act as catalysts for spiritual awakening*
# >
# >**4* Sensitive and Empathetic Individuals:**
# >* Those who possess a heightened sensitivity to the emotions and experiences of others*
# >* Their empathy and compassion can foster a deeper connection with the world and the divine*
# >
# >**5* Mystics and Visionaries:**
# ...

# %%
response.prompt_feedback

# %%
response.candidates
# Out:
# [content {
#   parts {
# ...

# %%
for chunk in response:
    print(chunk.text)
    print("_"*800)
# Out:
# **Individuals who can potentially experience spiritual enlightenment:**
#
# **1. Seekers and Practitioners:**
# * Those dedicated to spiritual practices, meditation, yoga, prayer, or other forms of contemplative inquiry.
#
# **2. Introspective Persons:**
# * Individuals with a strong inner life who engage in self-reflection, self-awareness, and a search for meaning.
#
# **3. Experiencers of Significant Life Events:**
# * People who undergo transformative experiences such as near-death experiences, profound grief, or major personal challenges.
# * These events can act as catalysts for spiritual awakening.
#
# **4. Sensitive and Empathetic Individuals:**
# * Those who possess a heightened sensitivity to the emotions and experiences of others.
# * Their empathy and compassion can foster a deeper connection with the world and the divine.
#
# **5. Mystics and Visionaries:**
# * Individuals with extraordinary mystical or visionary experiences that transcend ordinary reality.
# ...

# %%
try:
  response.text
except Exception as e:
  print(f'{type(e).__name__}: (e)')

# %%
# !pip install Pillow

# %%
from PIL import Image
img = Image.open("/content/preety_img (1).jpeg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=864x1152>

# %%
model = genai.GenerativeModel('gemini-1.5-flash')

# %%
response = model.generate_content(img)
to_markdown(response.text)
# Out:
# >This is a photo of a young woman wearing a striped sweater and a black fur vest* She's looking directly at the camera and smiling* Her hair is dark and pulled back from her face* The photo is taken indoors in front of a red curtain*

# %%
response = model.generate_content(["Write a short, engaging blog post based on this picture. It should include a description.", img], stream=True)
response.resolve()

# %%
to_markdown(response.text)
# Out:
# >## Cozy Up This Winter
# >
# >This photo captures the essence of a cold winter day*  The woman in the picture looks warm and cozy in her black fur vest and striped shirt* The red curtains in the background add a touch of warmth and vibrancy to the image* The soft lighting creates a sense of intimacy and comfort*
# >
# >The woman's smile is genuine and inviting, radiating a sense of calmness and joy* The image reminds us that even on the coldest days, there's always something to smile about*
